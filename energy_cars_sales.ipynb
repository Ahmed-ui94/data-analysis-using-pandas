# %%
import pandas as pd
import numpy as np
import pyarrow as prr
# Out:
# /Users/ahmedabukar/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("/Users/ahmedabukar/Downloads/IEA-EV-dataEV salesHistoricalCars.csv", engine="pyarrow")

# %%
df.loc[df["parameter"].isin(["EV sales", "EV stock"])]
# Out:
#          region    category parameter  mode powertrain  year      unit  \
# 2     Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 3     Australia  Historical  EV stock  Cars        BEV  2011  Vehicles
# 4     Australia  Historical  EV stock  Cars        BEV  2012  Vehicles
# 5     Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 8     Australia  Historical  EV stock  Cars       PHEV  2012  Vehicles
# ...         ...         ...       ...   ...        ...   ...       ...
# 3793      World  Historical  EV stock  Cars        BEV  2023  Vehicles
# 3794      World  Historical  EV sales  Cars        BEV  2023  Vehicles
# 3795      World  Historical  EV stock  Cars       FCEV  2023  Vehicles
# 3796      World  Historical  EV sales  Cars       PHEV  2023  Vehicles
# 3797      World  Historical  EV stock  Cars       PHEV  2023  Vehicles
#
#            value
# 2           49.0
# 3           49.0
# 4          220.0
# 5          170.0
# 8           80.0
# ...

# %%
df = df.drop(df[df["region"] == "World"].index)

# %%
df = df.drop(df.loc[~df["parameter"].isin(["EV sales", "EV stock"])].index)

# %%
df["parameter"].value_counts()
# Out:
# parameter
# EV sales    1300
# EV stock    1103
# Name: count, dtype: int64

# %%
df
# Out:
#          region    category parameter  mode powertrain  year      unit  \
# 2     Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 3     Australia  Historical  EV stock  Cars        BEV  2011  Vehicles
# 4     Australia  Historical  EV stock  Cars        BEV  2012  Vehicles
# 5     Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 8     Australia  Historical  EV stock  Cars       PHEV  2012  Vehicles
# ...         ...         ...       ...   ...        ...   ...       ...
# 3638        USA  Historical  EV stock  Cars       PHEV  2023  Vehicles
# 3640        USA  Historical  EV stock  Cars       FCEV  2023  Vehicles
# 3641        USA  Historical  EV sales  Cars       FCEV  2023  Vehicles
# 3642        USA  Historical  EV stock  Cars        BEV  2023  Vehicles
# 3643        USA  Historical  EV sales  Cars        BEV  2023  Vehicles
#
#           value
# 2          49.0
# 3          49.0
# 4         220.0
# 5         170.0
# 8          80.0
# ...

# %%
df["powertrain"].value_counts(normalize=True) * 100
# Out:
# powertrain
# BEV     43.695381
# PHEV    37.203496
# FCEV    19.101124
# Name: proportion, dtype: float64

# %%
#On which years are our sales the lowest?
df.groupby("year")["value"].sum()
# Out:
# year
# 2010       42128.0
# 2011      165601.0
# 2012      428600.0
# 2013      876440.0
# 2014     1512440.4
# 2015     2737262.0
# 2016     4031694.0
# 2017     6212047.0
# 2018     9699405.0
# 2019    13117981.0
# 2020    20710035.0
# 2021    36317395.0
# 2022    54625712.0
# 2023    78494464.0
# Name: value, dtype: float64
