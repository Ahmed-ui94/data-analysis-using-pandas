# %%
import pandas as pd
import numpy as np
import requests 
from io import StringIO
import pyarrow as pyrr

# %%
df = pd.read_csv("/Users/ahmedabukar/Downloads/ModalShare.csv", 
                 index_col=["region", "City", "Country"], engine="pyarrow")
df
# Out:
#                                                      CityID   ObsID  year  \
# region                      City           Country
# Europe                      Dippoldiswalde Germany   M10191  ID0156  2008
#                             Ljutomer       Slovenia  M10426  ID0382  2008
#                             Razlog         Bulgaria  M10596  ID0508  2013
#                             Kavarna        Bulgaria  M10364  ID0329  2013
#                             Balchik        Bulgaria  M10048  ID0040  2013
# ...                                                     ...     ...   ...
# Latin America and Caribbean Mexico City    Mexico    M10469  ID0419  2017
#                             São Paulo      Brazil    M10647  ID0536  2017
# East Asia and Pacific       Shanghai       China     M10656  ID0543  2009
# South Asia                  Delhi          India     M10184  ID0150  2011
# East Asia and Pacific       Tokyo          Japan     M10712  ID0584  2009
#
# ...

# %%
#how many distinct cities were represented in this research
len(df["CityID"].unique())
# Out:
# 794

# %%
#which 10 cities were surveyed the most times?abs
df.index.value_counts().head(10)
# Out:
# region  City         Country
# Europe  Graz         Austria           8
#         Vienna       Austria           6
#         Oslo         Norway            5
#         Erfurt       Germany           5
#         Leipzig      Germany           5
#         Dusseldorf   Germany           5
#         Frankfurt    Germany           4
#         Fredrikstad  Norway            4
#         London       United Kingdom    4
#         Hannover     Germany           4
# Name: count, dtype: int64
